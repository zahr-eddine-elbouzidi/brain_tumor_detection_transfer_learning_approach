# %%
# !pip install hdf5storage
# Out:
# Collecting hdf5storage
#   Downloading hdf5storage-0.1.18-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 575 kB/s eta 0:00:01
# Requirement already satisfied: h5py>=2.1 in /Users/zahr-eddine/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from hdf5storage) (3.1.0)
# Requirement already satisfied: numpy in /Users/zahr-eddine/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from hdf5storage) (1.19.5)
# Installing collected packages: hdf5storage
# Successfully installed hdf5storage-0.1.18

# %%
#!git clone https://github.com/adityajn105/brain-tumor-segmentation-unet
#!bash download_data.sh
# Out:
#     3064

# %%
# !python mat_to_numpy.py brain_tumor_dataset/
# Out:
# [3064/3064] images loaded: 100.0 %
# labels: (3064,)
# images: (3064, 512, 512)
# masks: (3064, 512, 512)
# labels.npy, images.npy, masks.npy saved in brain_tumor_dataset/

# %% [markdown]
# ### Librairies ###

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from skimage.transform import resize
from sklearn.model_selection import train_test_split
import gc
from keras.preprocessing.image import ImageDataGenerator
from keras_unet_collection import models , losses
from keras.models import load_model
from datetime import datetime
import time 
import tensorflow as tf

#init params
img_size_ori = 512
img_size_target = 128
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %% [markdown]
# ### Load Dataset ###

# %% [markdown]
# ### PreprocessingData Class ###

# %%
class PreprocessingData():
    
    def __init__(self):
        
        self.integer_to_class = {'1': 'meningioma', '2': 'glioma', '3': 'pituitary tumor'}
        self.labels = np.load('../brain_tumor_dataset/labels.npy')
        self.images = np.clip( (np.load('../brain_tumor_dataset/images.npy')/12728),0,1)
        self.masks = np.load('../brain_tumor_dataset/masks.npy')*1
        
        self.X = []
        self.X_v = []
        self.Y = []
        self.Y_v = []
        #print(self.labels.shape)
        #print(self.images.shape)
        #print(self.masks.shape)
        #reshape arrays 
        #X = np.stack((X,)*3 , axis = -1)
        
    def getUpDownSampling(self):
        
        self.images = np.expand_dims(self.images,axis=-1)
        self.masks = np.expand_dims(self.masks,axis=-1)
        #self.images = np.stack((self.images,)*3 , axis = -1)
        #self.masks = np.stack((self.masks,)*3 , axis = -1)
        
        def downsample(img):
            if img_size_ori == img_size_target:
                return img
            return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True,)
    
        def upsample(img):
            if img_size_ori == img_size_target:
                return img
            return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
  
        self.images = np.array([ downsample(image) for image in self.images ])
        self.masks = (np.array([ downsample(mask) for mask in self.masks ])>0)*1
        
        print(self.images.shape)
        print(self.masks.shape)  
        
        return self.images , self.masks
    
    #Split Data to Two parts Training set and Validation set 
    def splitData(self , size):
        
        self.X,self.X_v,self.Y,self.Y_v = train_test_split(self.images,self.masks,test_size=size,stratify=self.labels)
        gc.collect()
        return self.X,self.X_v,self.Y,self.Y_v
    
    def dataAugmentation(self , batch_s):
        
        self.X = np.append( self.X, [ np.fliplr(x) for x in self.X], axis=0 )
        self.Y = np.append( self.Y, [ np.fliplr(y) for y in self.Y], axis=0 )
        print(self.X.shape , self.Y.shape)
        #Data generation
        train_datagen = ImageDataGenerator(brightness_range=(0.9,1.1),
                                           zoom_range=[.9,1.1],
                                           fill_mode='nearest')
        val_datagen = ImageDataGenerator()
        
        train_generator = train_datagen.flow(self.X, self.Y, batch_size=batch_s)
        val_generator = val_datagen.flow(self.X_v, self.Y_v, batch_size=batch_s)
        
        return train_generator , val_generator

# %% [markdown]
# ### Call instance object from PreprocessingData Class ###

# %%
#create object instance from preprocessing data class 
processingObject = PreprocessingData()

# %%
#get images , masks arrays 
imgs , msks = processingObject.getUpDownSampling()
# Out:
# (3064, 128, 128, 1)
# (3064, 128, 128, 1)

# %% [markdown]
# #### Plot Labels ####

# %%
classes, counts = np.unique(processingObject.labels,return_counts=True)
plt.bar(classes,counts,tick_label=list(processingObject.integer_to_class.values()))
#print(counts)
#print(classes)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(12, 5))
for i, idx in enumerate(np.random.randint(imgs.shape[0], size=12), start=1):
    plt.subplot(3, 6, i)
    plt.imshow( np.squeeze(imgs[idx],axis=-1), cmap='gray')
    plt.imshow( np.squeeze(np.ones_like(msks[idx])-msks[idx],axis=-1), alpha=0.5, cmap='Set1')
    plt.title(processingObject.integer_to_class[str(processingObject.labels[idx])])
    plt.axis('off')

# %% [markdown]
# #### Train Image and its mask which is to be predicted ####

# %%
plt.figure(figsize=(12, 12))
i=1
for idx in np.random.randint( imgs.shape[0], size=9):
  plt.subplot(6,6,i);i+=1
  plt.imshow( np.squeeze(imgs[idx],axis=-1))
  plt.title("Image | "+processingObject.integer_to_class[str(processingObject.labels[idx])])
  plt.axis('off')
  plt.subplot(6,6,i);i+=1
  plt.imshow( np.squeeze(msks[idx],axis=-1)) 
  plt.title("Mask | "+processingObject.integer_to_class[str(processingObject.labels[idx])])
  plt.axis('off')

# %% [markdown]
# ### Split data ###

# %%
X,X_v,Y,Y_v = processingObject.splitData(0.2) #20% for validation set 
X.shape,X_v.shape,Y.shape,Y_v.shape
# Out:
# ((2451, 128, 128, 1),
#  (613, 128, 128, 1),
#  (2451, 128, 128, 1),
#  (613, 128, 128, 1))

# %% [markdown]
# ### Data Augmentation ###

# %%
train_generator , val_generator  = processingObject.dataAugmentation(32)
# Out:
# (4902, 128, 128, 1) (4902, 128, 128, 1)

# %% [markdown]
# ## Build Model Class ##

# %%
#Build Model Class 
class BuildModel():
    
    def __init__(self):
        self.model = None
        self.model_history = None
        
        
    def getModel(self, model_type , basedModel = None , output_classes = 1 , weights = None , freeze_backbone = False ,freeze_batch_norm = False ):
        
        if model_type == "AttentionUnet":
            
            #get Attention Unet Model
            self.model = models.att_unet_2d((128, 128, 1), 
                                                filter_num=[16,32,64, 128, 256],
                                                n_labels=output_classes,
                                                stack_num_down=2, 
                                                stack_num_up=2, 
                                                activation='ReLU', 
                                                atten_activation='ReLU', 
                                                attention='add', 
                                                output_activation='Sigmoid', 
                                                batch_norm=True, 
                                                pool=True, 
                                                unpool=True, 
                                                backbone=basedModel, 
                                                weights=weights, 
                                                freeze_backbone=freeze_backbone, 
                                                freeze_batch_norm=freeze_batch_norm, 
                                                name='BrainTumorAttUnet')
        elif model_type == "Unet++":
            
            self.model = models.unet_plus_2d((128, 128, 1), 
                                                filter_num=[16,32,64, 128, 256],
                                                n_labels=output_classes,
                                                stack_num_down=2, 
                                                stack_num_up=2, 
                                                activation='ReLU', 
                                                output_activation='Sigmoid', 
                                                batch_norm=True, 
                                                pool=True, 
                                                unpool=True, 
                                                backbone=basedModel, 
                                                weights=weights, 
                                                freeze_backbone=freeze_backbone, 
                                                freeze_batch_norm=freeze_batch_norm, 
                                                name='BrainTumorUnetPlusPlus')
        elif model_type == "Unet":
            
            
            self.model = models.unet_2d((128, 128, 1), 
                                                filter_num=[16,32,64, 128, 256],
                                                n_labels=output_classes,
                                                stack_num_down=2, 
                                                stack_num_up=2, 
                                                activation='ReLU', 
                                                output_activation='Sigmoid', 
                                                batch_norm=True, 
                                                pool=True, 
                                                unpool=True, 
                                                backbone=None, weights=None,
                                                freeze_backbone=False, freeze_batch_norm=False, 
                                                name='BrainTumorUnet')



          
            
            
  
        return self.model

    def trainingModel(self ,xtrain , ytrain , model_type , basedModel = None , output_classes = 1 , epochs = 50 ,  weights = None , freeze_backbone = False ,freeze_batch_norm = False):
        
        #get Model 
        self.getModel(model_type , basedModel, output_classes , weights , freeze_backbone , freeze_batch_norm )
        self.model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', losses.dice_coef])
        print(self.model.summary())
        #Build Model Fitting
        start = datetime.now() 
        callbacks= [tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss')]
        self.model_history = self.model.fit(xtrain, ytrain, 
                            verbose=1,
                            batch_size = 32,
                            validation_split=0.1, 
                            shuffle=False,
                            epochs=epochs, callbacks=callbacks)

        stop = datetime.now()
        #Execution time of the model 
        execution_time_att_Unet = stop-start
        print("Attention UNet execution time is: ", execution_time_att_Unet)
        
        t = time.time()
        
        file_model_path = "Best_Model_Save"
        if model_type == "AttentionUnet":
            file_model_path = '../Saved/Brain_Tumor_Att_UNet_50epochs.h5'.format(int(t))
            dataFrameScores = pd.DataFrame(self.model_history.history)
            with open('../Saved/brain_tumor_att_unet_history.csv', mode='w') as f:
                dataFrameScores.to_csv(f)
            
        elif model_type == "Unet++":
            file_model_path = '../Saved/Brain_Tumor_UNet++_50epochs.h5'.format(int(t))
            dataFrameScores = pd.DataFrame(self.model_history.history)
            with open('../Saved/brain_tumor_unetplusplus_history.csv', mode='w') as f:
                 dataFrameScores.to_csv(f)
            
        elif model_type == "Unet":
            file_model_path = '../Saved/Brain_Tumor_UNet_50epochs.h5'.format(int(t))
            dataFrameScores = pd.DataFrame(self.model_history.history)
            with open('../Saved/brain_tumor_unet_history.csv', mode='w') as f:
                 dataFrameScores.to_csv(f)
            
            
        print("Save Model Path : " , file_model_path)
        self.model.save(file_model_path)

# %% [markdown]
# ### Call Build Model Class ###

# %%
buildModel = BuildModel()

# %%
buildModel.trainingModel(
                        xtrain = X,
                        ytrain = Y,
                        model_type = 'AttentionUnet',
                        output_classes = 1 , 
                        epochs = 50 
                        
                        )
# Out:
# Model: "BrainTumorAttUnet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down0_0 (Conv (None, 128, 128, 16) 144         input_4[0][0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down0_0_bn (B (None, 128, 128, 16) 64          BrainTumorAttUnet_down0_0[0][0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down0_0_activ (None, 128, 128, 16) 0           BrainTumorAttUnet_down0_0_bn[0][0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down0_1 (Conv (None, 128, 128, 16) 2304        BrainTumorAttUnet_down0_0_activat
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down0_1_bn (B (None, 128, 128, 16) 64          BrainTumorAttUnet_down0_1[0][0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down0_1_activ (None, 128, 128, 16) 0           BrainTumorAttUnet_down0_1_bn[0][0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down1_encode_ (None, 64, 64, 16)   0           BrainTumorAttUnet_down0_1_activat
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down1_conv_0  (None, 64, 64, 32)   4608        BrainTumorAttUnet_down1_encode_ma
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down1_conv_0_ (None, 64, 64, 32)   128         BrainTumorAttUnet_down1_conv_0[0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down1_conv_0_ (None, 64, 64, 32)   0           BrainTumorAttUnet_down1_conv_0_bn
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down1_conv_1  (None, 64, 64, 32)   9216        BrainTumorAttUnet_down1_conv_0_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down1_conv_1_ (None, 64, 64, 32)   128         BrainTumorAttUnet_down1_conv_1[0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down1_conv_1_ (None, 64, 64, 32)   0           BrainTumorAttUnet_down1_conv_1_bn
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down2_encode_ (None, 32, 32, 32)   0           BrainTumorAttUnet_down1_conv_1_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down2_conv_0  (None, 32, 32, 64)   18432       BrainTumorAttUnet_down2_encode_ma
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down2_conv_0_ (None, 32, 32, 64)   256         BrainTumorAttUnet_down2_conv_0[0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down2_conv_0_ (None, 32, 32, 64)   0           BrainTumorAttUnet_down2_conv_0_bn
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down2_conv_1  (None, 32, 32, 64)   36864       BrainTumorAttUnet_down2_conv_0_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down2_conv_1_ (None, 32, 32, 64)   256         BrainTumorAttUnet_down2_conv_1[0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down2_conv_1_ (None, 32, 32, 64)   0           BrainTumorAttUnet_down2_conv_1_bn
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down3_encode_ (None, 16, 16, 64)   0           BrainTumorAttUnet_down2_conv_1_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down3_conv_0  (None, 16, 16, 128)  73728       BrainTumorAttUnet_down3_encode_ma
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down3_conv_0_ (None, 16, 16, 128)  512         BrainTumorAttUnet_down3_conv_0[0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down3_conv_0_ (None, 16, 16, 128)  0           BrainTumorAttUnet_down3_conv_0_bn
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down3_conv_1  (None, 16, 16, 128)  147456      BrainTumorAttUnet_down3_conv_0_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down3_conv_1_ (None, 16, 16, 128)  512         BrainTumorAttUnet_down3_conv_1[0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down3_conv_1_ (None, 16, 16, 128)  0           BrainTumorAttUnet_down3_conv_1_bn
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down4_encode_ (None, 8, 8, 128)    0           BrainTumorAttUnet_down3_conv_1_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down4_conv_0  (None, 8, 8, 256)    294912      BrainTumorAttUnet_down4_encode_ma
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down4_conv_0_ (None, 8, 8, 256)    1024        BrainTumorAttUnet_down4_conv_0[0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down4_conv_0_ (None, 8, 8, 256)    0           BrainTumorAttUnet_down4_conv_0_bn
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down4_conv_1  (None, 8, 8, 256)    589824      BrainTumorAttUnet_down4_conv_0_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down4_conv_1_ (None, 8, 8, 256)    1024        BrainTumorAttUnet_down4_conv_1[0]
# __________________________________________________________________________________________________
# BrainTumorAttUnet_down4_conv_1_ (None, 8, 8, 256)    0           BrainTumorAttUnet_down4_conv_1_bn
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_decode_un (None, 16, 16, 256)  0           BrainTumorAttUnet_down4_conv_1_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_att_theta (None, 16, 16, 64)   8256        BrainTumorAttUnet_down3_conv_1_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_att_phi_g (None, 16, 16, 64)   16448       BrainTumorAttUnet_up0_decode_unpo
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_att_add ( (None, 16, 16, 64)   0           BrainTumorAttUnet_up0_att_theta_x
#                                                                  BrainTumorAttUnet_up0_att_phi_g[0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_att_activ (None, 16, 16, 64)   0           BrainTumorAttUnet_up0_att_add[0][
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_att_psi_f (None, 16, 16, 1)    65          BrainTumorAttUnet_up0_att_activat
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_att_sigmo (None, 16, 16, 1)    0           BrainTumorAttUnet_up0_att_psi_f[0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_att_maski (None, 16, 16, 128)  0           BrainTumorAttUnet_down3_conv_1_ac
#                                                                  BrainTumorAttUnet_up0_att_sigmoid
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_concat (C (None, 16, 16, 384)  0           BrainTumorAttUnet_up0_decode_unpo
#                                                                  BrainTumorAttUnet_up0_att_masking
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_conv_afte (None, 16, 16, 128)  442368      BrainTumorAttUnet_up0_concat[0][0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_conv_afte (None, 16, 16, 128)  512         BrainTumorAttUnet_up0_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_conv_afte (None, 16, 16, 128)  0           BrainTumorAttUnet_up0_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_conv_afte (None, 16, 16, 128)  147456      BrainTumorAttUnet_up0_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_conv_afte (None, 16, 16, 128)  512         BrainTumorAttUnet_up0_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up0_conv_afte (None, 16, 16, 128)  0           BrainTumorAttUnet_up0_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_decode_un (None, 32, 32, 128)  0           BrainTumorAttUnet_up0_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_att_theta (None, 32, 32, 32)   2080        BrainTumorAttUnet_down2_conv_1_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_att_phi_g (None, 32, 32, 32)   4128        BrainTumorAttUnet_up1_decode_unpo
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_att_add ( (None, 32, 32, 32)   0           BrainTumorAttUnet_up1_att_theta_x
#                                                                  BrainTumorAttUnet_up1_att_phi_g[0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_att_activ (None, 32, 32, 32)   0           BrainTumorAttUnet_up1_att_add[0][
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_att_psi_f (None, 32, 32, 1)    33          BrainTumorAttUnet_up1_att_activat
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_att_sigmo (None, 32, 32, 1)    0           BrainTumorAttUnet_up1_att_psi_f[0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_att_maski (None, 32, 32, 64)   0           BrainTumorAttUnet_down2_conv_1_ac
#                                                                  BrainTumorAttUnet_up1_att_sigmoid
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_concat (C (None, 32, 32, 192)  0           BrainTumorAttUnet_up1_decode_unpo
#                                                                  BrainTumorAttUnet_up1_att_masking
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_conv_afte (None, 32, 32, 64)   110592      BrainTumorAttUnet_up1_concat[0][0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_conv_afte (None, 32, 32, 64)   256         BrainTumorAttUnet_up1_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_conv_afte (None, 32, 32, 64)   0           BrainTumorAttUnet_up1_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_conv_afte (None, 32, 32, 64)   36864       BrainTumorAttUnet_up1_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_conv_afte (None, 32, 32, 64)   256         BrainTumorAttUnet_up1_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up1_conv_afte (None, 32, 32, 64)   0           BrainTumorAttUnet_up1_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_decode_un (None, 64, 64, 64)   0           BrainTumorAttUnet_up1_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_att_theta (None, 64, 64, 16)   528         BrainTumorAttUnet_down1_conv_1_ac
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_att_phi_g (None, 64, 64, 16)   1040        BrainTumorAttUnet_up2_decode_unpo
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_att_add ( (None, 64, 64, 16)   0           BrainTumorAttUnet_up2_att_theta_x
#                                                                  BrainTumorAttUnet_up2_att_phi_g[0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_att_activ (None, 64, 64, 16)   0           BrainTumorAttUnet_up2_att_add[0][
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_att_psi_f (None, 64, 64, 1)    17          BrainTumorAttUnet_up2_att_activat
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_att_sigmo (None, 64, 64, 1)    0           BrainTumorAttUnet_up2_att_psi_f[0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_att_maski (None, 64, 64, 32)   0           BrainTumorAttUnet_down1_conv_1_ac
#                                                                  BrainTumorAttUnet_up2_att_sigmoid
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_concat (C (None, 64, 64, 96)   0           BrainTumorAttUnet_up2_decode_unpo
#                                                                  BrainTumorAttUnet_up2_att_masking
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_conv_afte (None, 64, 64, 32)   27648       BrainTumorAttUnet_up2_concat[0][0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_conv_afte (None, 64, 64, 32)   128         BrainTumorAttUnet_up2_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_conv_afte (None, 64, 64, 32)   0           BrainTumorAttUnet_up2_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_conv_afte (None, 64, 64, 32)   9216        BrainTumorAttUnet_up2_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_conv_afte (None, 64, 64, 32)   128         BrainTumorAttUnet_up2_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up2_conv_afte (None, 64, 64, 32)   0           BrainTumorAttUnet_up2_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_decode_un (None, 128, 128, 32) 0           BrainTumorAttUnet_up2_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_att_theta (None, 128, 128, 8)  136         BrainTumorAttUnet_down0_1_activat
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_att_phi_g (None, 128, 128, 8)  264         BrainTumorAttUnet_up3_decode_unpo
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_att_add ( (None, 128, 128, 8)  0           BrainTumorAttUnet_up3_att_theta_x
#                                                                  BrainTumorAttUnet_up3_att_phi_g[0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_att_activ (None, 128, 128, 8)  0           BrainTumorAttUnet_up3_att_add[0][
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_att_psi_f (None, 128, 128, 1)  9           BrainTumorAttUnet_up3_att_activat
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_att_sigmo (None, 128, 128, 1)  0           BrainTumorAttUnet_up3_att_psi_f[0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_att_maski (None, 128, 128, 16) 0           BrainTumorAttUnet_down0_1_activat
#                                                                  BrainTumorAttUnet_up3_att_sigmoid
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_concat (C (None, 128, 128, 48) 0           BrainTumorAttUnet_up3_decode_unpo
#                                                                  BrainTumorAttUnet_up3_att_masking
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_conv_afte (None, 128, 128, 16) 6912        BrainTumorAttUnet_up3_concat[0][0
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_conv_afte (None, 128, 128, 16) 64          BrainTumorAttUnet_up3_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_conv_afte (None, 128, 128, 16) 0           BrainTumorAttUnet_up3_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_conv_afte (None, 128, 128, 16) 2304        BrainTumorAttUnet_up3_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_conv_afte (None, 128, 128, 16) 64          BrainTumorAttUnet_up3_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_up3_conv_afte (None, 128, 128, 16) 0           BrainTumorAttUnet_up3_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_output (Conv2 (None, 128, 128, 1)  17          BrainTumorAttUnet_up3_conv_after_
# __________________________________________________________________________________________________
# BrainTumorAttUnet_output_activa (None, 128, 128, 1)  0           BrainTumorAttUnet_output[0][0]
# ==================================================================================================
# Total params: 1,999,757
# Trainable params: 1,996,813
# Non-trainable params: 2,944
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 2022-09-17 23:11:31.693251: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 69/69 [==============================] - ETA: 0s - loss: 0.3123 - accuracy: 0.9517 - dice_coef: 0.0484
# 2022-09-17 23:12:00.527957: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 69/69 [==============================] - 31s 410ms/step - loss: 0.3123 - accuracy: 0.9517 - dice_coef: 0.0484 - val_loss: 0.8209 - val_accuracy: 0.2809 - val_dice_coef: 0.0521
# Epoch 2/50
# 69/69 [==============================] - 27s 390ms/step - loss: 0.1755 - accuracy: 0.9743 - dice_coef: 0.0641 - val_loss: 0.3211 - val_accuracy: 0.9765 - val_dice_coef: 0.0511
# Epoch 3/50
# 69/69 [==============================] - 27s 385ms/step - loss: 0.1315 - accuracy: 0.9745 - dice_coef: 0.1000 - val_loss: 0.1850 - val_accuracy: 0.9765 - val_dice_coef: 0.0944
# Epoch 4/50
# 69/69 [==============================] - 27s 391ms/step - loss: 0.1012 - accuracy: 0.9781 - dice_coef: 0.1700 - val_loss: 0.1223 - val_accuracy: 0.9760 - val_dice_coef: 0.0472
# Epoch 5/50
# 69/69 [==============================] - 28s 396ms/step - loss: 0.0809 - accuracy: 0.9808 - dice_coef: 0.2570 - val_loss: 0.1199 - val_accuracy: 0.9723 - val_dice_coef: 0.0475
# Epoch 6/50
# 69/69 [==============================] - 25s 368ms/step - loss: 0.0666 - accuracy: 0.9831 - dice_coef: 0.3415 - val_loss: 0.1149 - val_accuracy: 0.9706 - val_dice_coef: 0.0518
# Epoch 7/50
# 69/69 [==============================] - 26s 377ms/step - loss: 0.0563 - accuracy: 0.9850 - dice_coef: 0.4138 - val_loss: 0.0877 - val_accuracy: 0.9786 - val_dice_coef: 0.1385
# Epoch 8/50
# 69/69 [==============================] - 26s 371ms/step - loss: 0.0477 - accuracy: 0.9867 - dice_coef: 0.4797 - val_loss: 0.0869 - val_accuracy: 0.9792 - val_dice_coef: 0.1825
# Epoch 9/50
# 69/69 [==============================] - 25s 368ms/step - loss: 0.0411 - accuracy: 0.9882 - dice_coef: 0.5368 - val_loss: 0.0752 - val_accuracy: 0.9810 - val_dice_coef: 0.2874
# Epoch 10/50
# 69/69 [==============================] - 26s 366ms/step - loss: 0.0359 - accuracy: 0.9895 - dice_coef: 0.5881 - val_loss: 0.0536 - val_accuracy: 0.9850 - val_dice_coef: 0.4499
# Epoch 11/50
# 69/69 [==============================] - 26s 366ms/step - loss: 0.0332 - accuracy: 0.9899 - dice_coef: 0.6150 - val_loss: 0.0404 - val_accuracy: 0.9882 - val_dice_coef: 0.5617
# Epoch 12/50
# 69/69 [==============================] - 25s 363ms/step - loss: 0.0291 - accuracy: 0.9911 - dice_coef: 0.6557 - val_loss: 0.0370 - val_accuracy: 0.9875 - val_dice_coef: 0.5950
# Epoch 13/50
# 69/69 [==============================] - 25s 364ms/step - loss: 0.0262 - accuracy: 0.9917 - dice_coef: 0.6871 - val_loss: 0.0342 - val_accuracy: 0.9888 - val_dice_coef: 0.6250
# Epoch 14/50
# 69/69 [==============================] - 25s 363ms/step - loss: 0.0244 - accuracy: 0.9921 - dice_coef: 0.7067 - val_loss: 0.0335 - val_accuracy: 0.9886 - val_dice_coef: 0.6590
# Epoch 15/50
# 69/69 [==============================] - 25s 366ms/step - loss: 0.0222 - accuracy: 0.9928 - dice_coef: 0.7344 - val_loss: 0.0348 - val_accuracy: 0.9880 - val_dice_coef: 0.6431
# Epoch 16/50
# 69/69 [==============================] - 25s 364ms/step - loss: 0.0212 - accuracy: 0.9928 - dice_coef: 0.7431 - val_loss: 0.0347 - val_accuracy: 0.9893 - val_dice_coef: 0.6418
# Epoch 17/50
# 69/69 [==============================] - 25s 364ms/step - loss: 0.0203 - accuracy: 0.9930 - dice_coef: 0.7537 - val_loss: 0.0355 - val_accuracy: 0.9894 - val_dice_coef: 0.6644
# Epoch 18/50
# 69/69 [==============================] - 25s 364ms/step - loss: 0.0190 - accuracy: 0.9934 - dice_coef: 0.7695 - val_loss: 0.0291 - val_accuracy: 0.9904 - val_dice_coef: 0.7052
# Epoch 19/50
# 69/69 [==============================] - 25s 361ms/step - loss: 0.0180 - accuracy: 0.9937 - dice_coef: 0.7814 - val_loss: 0.0302 - val_accuracy: 0.9895 - val_dice_coef: 0.6986
# Epoch 20/50
# 69/69 [==============================] - 25s 365ms/step - loss: 0.0168 - accuracy: 0.9940 - dice_coef: 0.7945 - val_loss: 0.0289 - val_accuracy: 0.9905 - val_dice_coef: 0.7116
# Epoch 21/50
# 69/69 [==============================] - 25s 363ms/step - loss: 0.0159 - accuracy: 0.9943 - dice_coef: 0.8060 - val_loss: 0.0419 - val_accuracy: 0.9870 - val_dice_coef: 0.6326
# Epoch 22/50
# 69/69 [==============================] - 25s 366ms/step - loss: 0.0149 - accuracy: 0.9946 - dice_coef: 0.8176 - val_loss: 0.0366 - val_accuracy: 0.9890 - val_dice_coef: 0.6698
# Epoch 23/50
# 69/69 [==============================] - 25s 364ms/step - loss: 0.0145 - accuracy: 0.9947 - dice_coef: 0.8231 - val_loss: 0.0384 - val_accuracy: 0.9890 - val_dice_coef: 0.6769
# Epoch 24/50
# 69/69 [==============================] - 25s 361ms/step - loss: 0.0137 - accuracy: 0.9949 - dice_coef: 0.8312 - val_loss: 0.0296 - val_accuracy: 0.9904 - val_dice_coef: 0.7170
# Epoch 25/50
# 69/69 [==============================] - 25s 364ms/step - loss: 0.0126 - accuracy: 0.9953 - dice_coef: 0.8440 - val_loss: 0.0295 - val_accuracy: 0.9901 - val_dice_coef: 0.7364
# Attention UNet execution time is:  0:10:45.196699
# Save Model Path :  ../Saved/Brain_Tumor_Att_UNet_50epochs.h5
# /Users/zahr-eddine/miniforge3/envs/tensorflow/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '

# %% [markdown]
# ## Performance Accuracy, Loss , Dice ##

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4))
t = f.suptitle('Unet Performance in Segmentation', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
history = buildModel.model_history
epoch_list = history.epoch

#for Accuracy
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, epoch_list[-1], 5))
ax1.set_ylabel('Accuracy Value');ax1.set_xlabel('Epoch');ax1.set_title('Accuracy')
ax1.legend(loc="best");ax1.grid(color='gray', linestyle='-', linewidth=0.5)

#for Loss
ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('Loss Value');ax2.set_xlabel('Epoch');ax2.set_title('Loss')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)


#for Dice Loss
ax3.plot(epoch_list, history.history['dice_coef'], label='Dice Loss')
ax3.plot(epoch_list, history.history['val_dice_coef'], label='Validation Dice Loss')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('Dice Loss Value');ax2.set_xlabel('Epoch');ax2.set_title('Loss')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
import pandas as pd
df = pd.read_csv("../saved/brain_tumor_att_unet_history.csv" , sep = ",")
plt.figure(figsize=(15, 5))
plt.plot(df.loss , 'b', label='Training loss')
plt.plot(df.val_loss, 'y', label='Validation loss')
plt.plot(df.dice_coef, 'r', label='Training Dice Coeff')
plt.plot(df.val_dice_coef , 'g', label='Validation Dice Coeff')
plt.title('LOSS / DICE COEFFICIENT', size=20)
plt.xlabel('Epochs', size=15)
plt.ylabel('Dice coefficient/ Loss', size=15)
plt.legend(loc="best");plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.show()

# %% [markdown]
# ## Load Model ##

# %%
unet_model = load_model('../Saved/Brain_Tumor_UNet_50epochs.h5', compile=False) #or compile = False
unet_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', losses.dice_coef])

# %% [markdown]
# ## Predict Model ##

# %%
import random


idx = random.randint(0, len(X))
preds_train = unet_model.predict(X[:int(X.shape[0]*0.9)], verbose=1)
preds_val = unet_model.predict(X[int(X.shape[0]*0.9):], verbose=1)
preds_test = unet_model.predict(X_v, verbose=1)
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
# Out:
# 2022-09-18 00:03:01.736223: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 69/69 [==============================] - 10s 78ms/step
# 8/8 [==============================] - 1s 90ms/step
# 20/20 [==============================] - 2s 86ms/step

# %%
ids = [752, 454, 887,100]
temp = np.ones_like( Y_v[0] )
THRESHOLD = 0.5
predicted_mask = (unet_model.predict(X_v)>THRESHOLD)*1

# %%
plt.figure(figsize=(14, 14))
j=1
total=4
for i in range(0,len(ids)):
    plt.subplot(total,4,j);j+=1
    plt.imshow( np.squeeze(X_v[i],axis=-1), cmap='gray' )
    plt.title("MRI Image");plt.axis('off')

    plt.subplot(total,4,j);j+=1
    plt.imshow( np.squeeze(X_v[i],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - Y_v[i],axis=-1), alpha=0.2, cmap='Set1' )
    plt.title("Original Mask");plt.axis('off')

    plt.subplot(total,4,j);j+=1
    plt.imshow( np.squeeze(predicted_mask[i],axis=-1), cmap='gray' )
    plt.title("Predicted Mask");plt.axis('off')
    
    plt.subplot(total,4,j);j+=1
    plt.imshow( np.squeeze(X_v[i],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - predicted_mask[i],axis=-1),  alpha=0.2 ,  cmap='Set1')
    plt.title("Predicted Mask - "+processingObject.integer_to_class[str(processingObject.labels[i])]);plt.axis('off')
