# %%
# !pip install hdf5storage
# Out:
# Collecting hdf5storage
#   Downloading hdf5storage-0.1.18-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 575 kB/s eta 0:00:01
# Requirement already satisfied: h5py>=2.1 in /Users/zahr-eddine/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from hdf5storage) (3.1.0)
# Requirement already satisfied: numpy in /Users/zahr-eddine/miniforge3/envs/tensorflow/lib/python3.9/site-packages (from hdf5storage) (1.19.5)
# Installing collected packages: hdf5storage
# Successfully installed hdf5storage-0.1.18

# %%
#!git clone https://github.com/adityajn105/brain-tumor-segmentation-unet
#!bash download_data.sh
# Out:
#     3064

# %%
# !python mat_to_numpy.py brain_tumor_dataset/
# Out:
# [3064/3064] images loaded: 100.0 %
# labels: (3064,)
# images: (3064, 512, 512)
# masks: (3064, 512, 512)
# labels.npy, images.npy, masks.npy saved in brain_tumor_dataset/

# %% [markdown]
# ### Librairies ###

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from skimage.transform import resize
from sklearn.model_selection import train_test_split
import gc
from keras.preprocessing.image import ImageDataGenerator
from keras_unet_collection import models , losses
from keras.models import load_model
from datetime import datetime
import time 
import tensorflow as tf

#init params
img_size_ori = 512
img_size_target = 128

# %% [markdown]
# ### Load Dataset ###

# %% [markdown]
# ### PreprocessingData Class ###

# %%
class PreprocessingData():
    
    def __init__(self):
        
        self.integer_to_class = {'1': 'meningioma', '2': 'glioma', '3': 'pituitary tumor'}
        self.labels = np.load('brain_tumor_dataset/labels.npy')
        self.images = np.clip( (np.load('brain_tumor_dataset/images.npy')/12728),0,1)
        self.masks = np.load('brain_tumor_dataset/masks.npy')*1
        
        self.X = []
        self.X_v = []
        self.Y = []
        self.Y_v = []
        #print(self.labels.shape)
        #print(self.images.shape)
        #print(self.masks.shape)
        #reshape arrays 
        #X = np.stack((X,)*3 , axis = -1)
        
    def getUpDownSampling(self):
        
        self.images = np.expand_dims(self.images,axis=-1)
        self.masks = np.expand_dims(self.masks,axis=-1)
        #self.images = np.stack((self.images,)*3 , axis = -1)
        #self.masks = np.stack((self.masks,)*3 , axis = -1)
        
        def downsample(img):
            if img_size_ori == img_size_target:
                return img
            return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True,)
    
        def upsample(img):
            if img_size_ori == img_size_target:
                return img
            return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
  
        self.images = np.array([ downsample(image) for image in self.images ])
        self.masks = (np.array([ downsample(mask) for mask in self.masks ])>0)*1
        
        print(self.images.shape)
        print(self.masks.shape)  
        
        return self.images , self.masks
    
    #Split Data to Two parts Training set and Validation set 
    def splitData(self , size):
        
        self.X,self.X_v,self.Y,self.Y_v = train_test_split(self.images,self.masks,test_size=size,stratify=self.labels)
        gc.collect()
        return self.X,self.X_v,self.Y,self.Y_v
    
    def dataAugmentation(self , batch_s):
        
        self.X = np.append( self.X, [ np.fliplr(x) for x in self.X], axis=0 )
        self.Y = np.append( self.Y, [ np.fliplr(y) for y in self.Y], axis=0 )
        print(self.X.shape , self.Y.shape)
        #Data generation
        train_datagen = ImageDataGenerator(brightness_range=(0.9,1.1),
                                           zoom_range=[.9,1.1],
                                           fill_mode='nearest')
        val_datagen = ImageDataGenerator()
        
        train_generator = train_datagen.flow(self.X, self.Y, batch_size=batch_s)
        val_generator = val_datagen.flow(self.X_v, self.Y_v, batch_size=batch_s)
        
        return train_generator , val_generator

# %% [markdown]
# ### Call instance object from PreprocessingData Class ###

# %%
#create object instance from preprocessing data class 
processingObject = PreprocessingData()

# %%
#get images , masks arrays 
imgs , msks = processingObject.getUpDownSampling()
# Out:
# (3064, 128, 128, 1)
# (3064, 128, 128, 1)

# %% [markdown]
# #### Plot Labels ####

# %%
classes, counts = np.unique(processingObject.labels,return_counts=True)
plt.bar(classes,counts,tick_label=list(processingObject.integer_to_class.values()))
#print(counts)
#print(classes)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(12, 5))
for i, idx in enumerate(np.random.randint(imgs.shape[0], size=12), start=1):
    plt.subplot(3, 6, i)
    plt.imshow( np.squeeze(imgs[idx],axis=-1), cmap='gray')
    plt.imshow( np.squeeze(np.ones_like(msks[idx])-msks[idx],axis=-1), alpha=0.5, cmap='Set1')
    plt.title(processingObject.integer_to_class[str(processingObject.labels[idx])])
    plt.axis('off')

# %% [markdown]
# #### Train Image and its mask which is to be predicted ####

# %%
plt.figure(figsize=(12, 12))
i=1
for idx in np.random.randint( imgs.shape[0], size=9):
  plt.subplot(6,6,i);i+=1
  plt.imshow( np.squeeze(imgs[idx],axis=-1))
  plt.title("Image | "+processingObject.integer_to_class[str(processingObject.labels[idx])])
  plt.axis('off')
  plt.subplot(6,6,i);i+=1
  plt.imshow( np.squeeze(msks[idx],axis=-1)) 
  plt.title("Mask | "+processingObject.integer_to_class[str(processingObject.labels[idx])])
  plt.axis('off')

# %% [markdown]
# ### Split data ###

# %%
X,X_v,Y,Y_v = processingObject.splitData(0.3) #20% for validation set 
X.shape,X_v.shape,Y.shape,Y_v.shape
# Out:
# ((2144, 128, 128, 1),
#  (920, 128, 128, 1),
#  (2144, 128, 128, 1),
#  (920, 128, 128, 1))

# %% [markdown]
# ### Data Augmentation ###

# %%
train_generator , val_generator  = processingObject.dataAugmentation(32)
# Out:
# (4902, 128, 128, 1) (4902, 128, 128, 1)

# %% [markdown]
# ## Build Model Class ##

# %%
#Build Model Class 
class BuildModel():
    
    def __init__(self):
        self.model = None
        self.model_history = None
        
        
    def getModel(self, model_type , basedModel = None , output_classes = 1 , weights = None , freeze_backbone = False ,freeze_batch_norm = False ):
        
        if model_type == "AttentionUnet":
            
            #get Attention Unet Model
            self.model = models.att_unet_2d((128, 128, 1), 
                                                filter_num=[16,32,64, 128, 256],
                                                n_labels=output_classes,
                                                stack_num_down=2, 
                                                stack_num_up=2, 
                                                activation='ReLU', 
                                                atten_activation='ReLU', 
                                                attention='add', 
                                                output_activation='Sigmoid', 
                                                batch_norm=True, 
                                                pool=True, 
                                                unpool=True, 
                                                backbone=basedModel, 
                                                weights=weights, 
                                                freeze_backbone=freeze_backbone, 
                                                freeze_batch_norm=freeze_batch_norm, 
                                                name='BrainTumorAttUnet')
        elif model_type == "Unet++":
            
            self.model = models.unet_plus_2d((128, 128, 1), 
                                                filter_num=[16,32,64, 128, 256],
                                                n_labels=output_classes,
                                                stack_num_down=2, 
                                                stack_num_up=2, 
                                                activation='ReLU', 
                                                output_activation='Sigmoid', 
                                                batch_norm=True, 
                                                pool=True, 
                                                unpool=True, 
                                                backbone=basedModel, 
                                                weights=weights, 
                                                freeze_backbone=freeze_backbone, 
                                                freeze_batch_norm=freeze_batch_norm, 
                                                name='BrainTumorUnetPlusPlus')
        elif model_type == "Unet":
            
            
            self.model = models.unet_2d((128, 128, 1), 
                                                filter_num=[16,32,64, 128, 256],
                                                n_labels=output_classes,
                                                stack_num_down=2, 
                                                stack_num_up=2, 
                                                activation='ReLU', 
                                                output_activation='Sigmoid', 
                                                batch_norm=True, 
                                                pool=True, 
                                                unpool=True, 
                                                backbone=None, weights=None,
                                                freeze_backbone=False, freeze_batch_norm=False, 
                                                name='BrainTumorUnet')



          
            
            
  
        return self.model

    def trainingModel(self ,xtrain , ytrain , model_type , basedModel = None , output_classes = 1 , epochs = 50 ,  weights = None , freeze_backbone = False ,freeze_batch_norm = False):
        
        #get Model 
        self.getModel(model_type , basedModel, output_classes , weights , freeze_backbone , freeze_batch_norm )
        self.model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', losses.dice_coef])
        print(self.model.summary())
        #Build Model Fitting
        start = datetime.now() 
        callbacks= [tf.keras.callbacks.EarlyStopping(patience=5, monitor='val_loss')]
        self.model_history = self.model.fit(xtrain, ytrain, 
                            verbose=1,
                            batch_size = 32,
                            validation_split=0.1, 
                            shuffle=False,
                            epochs=epochs, callbacks=callbacks)

        stop = datetime.now()
        #Execution time of the model 
        execution_time_att_Unet = stop-start
        print("Attention UNet execution time is: ", execution_time_att_Unet)
        
        t = time.time()
        
        file_model_path = "Best_Model_Save"
        if model_type == "AttentionUnet":
            file_model_path = 'Brain_Tumor_Att_UNet_50epochs.h5'.format(int(t))
            dataFrameScores = pd.DataFrame(self.model_history.history)
            with open('brain_tumor_att_unet_history.csv', mode='w') as f:
                dataFrameScores.to_csv(f)
            
        elif model_type == "Unet++":
            file_model_path = 'Brain_Tumor_UNet++_50epochs.h5'.format(int(t))
            dataFrameScores = pd.DataFrame(self.model_history.history)
            with open('brain_tumor_unetplusplus_history.csv', mode='w') as f:
                 dataFrameScores.to_csv(f)
            
        elif model_type == "Unet":
            file_model_path = 'Brain_Tumor_UNet_50epochs.h5'.format(int(t))
            dataFrameScores = pd.DataFrame(self.model_history.history)
            with open('brain_tumor_unet_history.csv', mode='w') as f:
                 dataFrameScores.to_csv(f)
            
            
        print("Save Model Path : " , file_model_path)
        self.model.save(file_model_path)

# %% [markdown]
# ### Call Build Model Class ###

# %%
buildModel = BuildModel()

# %%
buildModel.trainingModel(
                        xtrain = X,
                        ytrain = Y,
                        model_type = 'Unet',
                        output_classes = 1 , 
                        epochs = 50 
                        
                        )
# Out:
# Metal device set to: Apple M1
# 2022-09-17 20:20:27.703433: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-09-17 20:20:27.704214: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Model: "BrainTumorUnet_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# BrainTumorUnet_down0_0 (Conv2D) (None, 128, 128, 16) 144         input_1[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down0_0_bn (Batc (None, 128, 128, 16) 64          BrainTumorUnet_down0_0[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down0_0_activati (None, 128, 128, 16) 0           BrainTumorUnet_down0_0_bn[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down0_1 (Conv2D) (None, 128, 128, 16) 2304        BrainTumorUnet_down0_0_activation
# __________________________________________________________________________________________________
# BrainTumorUnet_down0_1_bn (Batc (None, 128, 128, 16) 64          BrainTumorUnet_down0_1[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down0_1_activati (None, 128, 128, 16) 0           BrainTumorUnet_down0_1_bn[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down1_encode_max (None, 64, 64, 16)   0           BrainTumorUnet_down0_1_activation
# __________________________________________________________________________________________________
# BrainTumorUnet_down1_conv_0 (Co (None, 64, 64, 32)   4608        BrainTumorUnet_down1_encode_maxpo
# __________________________________________________________________________________________________
# BrainTumorUnet_down1_conv_0_bn  (None, 64, 64, 32)   128         BrainTumorUnet_down1_conv_0[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down1_conv_0_act (None, 64, 64, 32)   0           BrainTumorUnet_down1_conv_0_bn[0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down1_conv_1 (Co (None, 64, 64, 32)   9216        BrainTumorUnet_down1_conv_0_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_down1_conv_1_bn  (None, 64, 64, 32)   128         BrainTumorUnet_down1_conv_1[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down1_conv_1_act (None, 64, 64, 32)   0           BrainTumorUnet_down1_conv_1_bn[0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down2_encode_max (None, 32, 32, 32)   0           BrainTumorUnet_down1_conv_1_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_down2_conv_0 (Co (None, 32, 32, 64)   18432       BrainTumorUnet_down2_encode_maxpo
# __________________________________________________________________________________________________
# BrainTumorUnet_down2_conv_0_bn  (None, 32, 32, 64)   256         BrainTumorUnet_down2_conv_0[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down2_conv_0_act (None, 32, 32, 64)   0           BrainTumorUnet_down2_conv_0_bn[0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down2_conv_1 (Co (None, 32, 32, 64)   36864       BrainTumorUnet_down2_conv_0_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_down2_conv_1_bn  (None, 32, 32, 64)   256         BrainTumorUnet_down2_conv_1[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down2_conv_1_act (None, 32, 32, 64)   0           BrainTumorUnet_down2_conv_1_bn[0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down3_encode_max (None, 16, 16, 64)   0           BrainTumorUnet_down2_conv_1_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_down3_conv_0 (Co (None, 16, 16, 128)  73728       BrainTumorUnet_down3_encode_maxpo
# __________________________________________________________________________________________________
# BrainTumorUnet_down3_conv_0_bn  (None, 16, 16, 128)  512         BrainTumorUnet_down3_conv_0[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down3_conv_0_act (None, 16, 16, 128)  0           BrainTumorUnet_down3_conv_0_bn[0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down3_conv_1 (Co (None, 16, 16, 128)  147456      BrainTumorUnet_down3_conv_0_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_down3_conv_1_bn  (None, 16, 16, 128)  512         BrainTumorUnet_down3_conv_1[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down3_conv_1_act (None, 16, 16, 128)  0           BrainTumorUnet_down3_conv_1_bn[0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down4_encode_max (None, 8, 8, 128)    0           BrainTumorUnet_down3_conv_1_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_down4_conv_0 (Co (None, 8, 8, 256)    294912      BrainTumorUnet_down4_encode_maxpo
# __________________________________________________________________________________________________
# BrainTumorUnet_down4_conv_0_bn  (None, 8, 8, 256)    1024        BrainTumorUnet_down4_conv_0[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down4_conv_0_act (None, 8, 8, 256)    0           BrainTumorUnet_down4_conv_0_bn[0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down4_conv_1 (Co (None, 8, 8, 256)    589824      BrainTumorUnet_down4_conv_0_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_down4_conv_1_bn  (None, 8, 8, 256)    1024        BrainTumorUnet_down4_conv_1[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_down4_conv_1_act (None, 8, 8, 256)    0           BrainTumorUnet_down4_conv_1_bn[0]
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_decode_unpoo (None, 16, 16, 256)  0           BrainTumorUnet_down4_conv_1_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_before_ (None, 16, 16, 128)  294912      BrainTumorUnet_up0_decode_unpool[
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_before_ (None, 16, 16, 128)  512         BrainTumorUnet_up0_conv_before_co
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_before_ (None, 16, 16, 128)  0           BrainTumorUnet_up0_conv_before_co
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_concat (Conc (None, 16, 16, 256)  0           BrainTumorUnet_up0_conv_before_co
#                                                                  BrainTumorUnet_down3_conv_1_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_after_c (None, 16, 16, 128)  294912      BrainTumorUnet_up0_concat[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_after_c (None, 16, 16, 128)  512         BrainTumorUnet_up0_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_after_c (None, 16, 16, 128)  0           BrainTumorUnet_up0_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_after_c (None, 16, 16, 128)  147456      BrainTumorUnet_up0_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_after_c (None, 16, 16, 128)  512         BrainTumorUnet_up0_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up0_conv_after_c (None, 16, 16, 128)  0           BrainTumorUnet_up0_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_decode_unpoo (None, 32, 32, 128)  0           BrainTumorUnet_up0_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_before_ (None, 32, 32, 64)   73728       BrainTumorUnet_up1_decode_unpool[
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_before_ (None, 32, 32, 64)   256         BrainTumorUnet_up1_conv_before_co
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_before_ (None, 32, 32, 64)   0           BrainTumorUnet_up1_conv_before_co
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_concat (Conc (None, 32, 32, 128)  0           BrainTumorUnet_up1_conv_before_co
#                                                                  BrainTumorUnet_down2_conv_1_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_after_c (None, 32, 32, 64)   73728       BrainTumorUnet_up1_concat[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_after_c (None, 32, 32, 64)   256         BrainTumorUnet_up1_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_after_c (None, 32, 32, 64)   0           BrainTumorUnet_up1_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_after_c (None, 32, 32, 64)   36864       BrainTumorUnet_up1_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_after_c (None, 32, 32, 64)   256         BrainTumorUnet_up1_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up1_conv_after_c (None, 32, 32, 64)   0           BrainTumorUnet_up1_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_decode_unpoo (None, 64, 64, 64)   0           BrainTumorUnet_up1_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_before_ (None, 64, 64, 32)   18432       BrainTumorUnet_up2_decode_unpool[
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_before_ (None, 64, 64, 32)   128         BrainTumorUnet_up2_conv_before_co
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_before_ (None, 64, 64, 32)   0           BrainTumorUnet_up2_conv_before_co
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_concat (Conc (None, 64, 64, 64)   0           BrainTumorUnet_up2_conv_before_co
#                                                                  BrainTumorUnet_down1_conv_1_activ
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_after_c (None, 64, 64, 32)   18432       BrainTumorUnet_up2_concat[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_after_c (None, 64, 64, 32)   128         BrainTumorUnet_up2_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_after_c (None, 64, 64, 32)   0           BrainTumorUnet_up2_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_after_c (None, 64, 64, 32)   9216        BrainTumorUnet_up2_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_after_c (None, 64, 64, 32)   128         BrainTumorUnet_up2_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up2_conv_after_c (None, 64, 64, 32)   0           BrainTumorUnet_up2_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_decode_unpoo (None, 128, 128, 32) 0           BrainTumorUnet_up2_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_before_ (None, 128, 128, 16) 4608        BrainTumorUnet_up3_decode_unpool[
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_before_ (None, 128, 128, 16) 64          BrainTumorUnet_up3_conv_before_co
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_before_ (None, 128, 128, 16) 0           BrainTumorUnet_up3_conv_before_co
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_concat (Conc (None, 128, 128, 32) 0           BrainTumorUnet_up3_conv_before_co
#                                                                  BrainTumorUnet_down0_1_activation
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_after_c (None, 128, 128, 16) 4608        BrainTumorUnet_up3_concat[0][0]
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_after_c (None, 128, 128, 16) 64          BrainTumorUnet_up3_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_after_c (None, 128, 128, 16) 0           BrainTumorUnet_up3_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_after_c (None, 128, 128, 16) 2304        BrainTumorUnet_up3_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_after_c (None, 128, 128, 16) 64          BrainTumorUnet_up3_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_up3_conv_after_c (None, 128, 128, 16) 0           BrainTumorUnet_up3_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_output (Conv2D)  (None, 128, 128, 1)  17          BrainTumorUnet_up3_conv_after_con
# __________________________________________________________________________________________________
# BrainTumorUnet_output_activatio (None, 128, 128, 1)  0           BrainTumorUnet_output[0][0]
# ==================================================================================================
# Total params: 2,163,553
# Trainable params: 2,160,129
# Non-trainable params: 3,424
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 2022-09-17 20:20:27.994481: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2022-09-17 20:20:27.997196: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-09-17 20:20:28.474887: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 61/61 [==============================] - ETA: 0s - loss: 0.3727 - accuracy: 0.9472 - dice_coef: 0.0472
# 2022-09-17 20:20:49.134536: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 61/61 [==============================] - 22s 341ms/step - loss: 0.3727 - accuracy: 0.9472 - dice_coef: 0.0472 - val_loss: 0.4599 - val_accuracy: 0.9760 - val_dice_coef: 0.0465
# Epoch 2/50
# 61/61 [==============================] - 21s 341ms/step - loss: 0.2226 - accuracy: 0.9744 - dice_coef: 0.0499 - val_loss: 0.2546 - val_accuracy: 0.9760 - val_dice_coef: 0.0437
# Epoch 3/50
# 61/61 [==============================] - 20s 327ms/step - loss: 0.1682 - accuracy: 0.9745 - dice_coef: 0.0621 - val_loss: 0.2366 - val_accuracy: 0.9760 - val_dice_coef: 0.0538
# Epoch 4/50
# 61/61 [==============================] - 20s 333ms/step - loss: 0.1303 - accuracy: 0.9745 - dice_coef: 0.1039 - val_loss: 0.2187 - val_accuracy: 0.9760 - val_dice_coef: 0.0794
# Epoch 5/50
# 61/61 [==============================] - 20s 331ms/step - loss: 0.1046 - accuracy: 0.9757 - dice_coef: 0.1528 - val_loss: 0.1940 - val_accuracy: 0.9528 - val_dice_coef: 0.1014
# Epoch 6/50
# 61/61 [==============================] - 20s 331ms/step - loss: 0.0868 - accuracy: 0.9800 - dice_coef: 0.2274 - val_loss: 0.1823 - val_accuracy: 0.9320 - val_dice_coef: 0.0862
# Epoch 7/50
# 61/61 [==============================] - 20s 333ms/step - loss: 0.0730 - accuracy: 0.9818 - dice_coef: 0.3006 - val_loss: 0.1112 - val_accuracy: 0.9758 - val_dice_coef: 0.0346
# Epoch 8/50
# 61/61 [==============================] - 20s 332ms/step - loss: 0.0620 - accuracy: 0.9835 - dice_coef: 0.3681 - val_loss: 0.0992 - val_accuracy: 0.9759 - val_dice_coef: 0.0997
# Epoch 9/50
# 61/61 [==============================] - 21s 346ms/step - loss: 0.0547 - accuracy: 0.9848 - dice_coef: 0.4204 - val_loss: 0.0930 - val_accuracy: 0.9766 - val_dice_coef: 0.1259
# Epoch 10/50
# 61/61 [==============================] - 21s 349ms/step - loss: 0.0485 - accuracy: 0.9860 - dice_coef: 0.4697 - val_loss: 0.0737 - val_accuracy: 0.9805 - val_dice_coef: 0.2525
# Epoch 11/50
# 61/61 [==============================] - 20s 332ms/step - loss: 0.0450 - accuracy: 0.9866 - dice_coef: 0.4995 - val_loss: 0.0546 - val_accuracy: 0.9843 - val_dice_coef: 0.4705
# Epoch 12/50
# 61/61 [==============================] - 20s 333ms/step - loss: 0.0388 - accuracy: 0.9884 - dice_coef: 0.5583 - val_loss: 0.0497 - val_accuracy: 0.9859 - val_dice_coef: 0.4846
# Epoch 13/50
# 61/61 [==============================] - 21s 339ms/step - loss: 0.0342 - accuracy: 0.9896 - dice_coef: 0.6021 - val_loss: 0.0466 - val_accuracy: 0.9848 - val_dice_coef: 0.5289
# Epoch 14/50
# 61/61 [==============================] - 20s 328ms/step - loss: 0.0317 - accuracy: 0.9901 - dice_coef: 0.6280 - val_loss: 0.0460 - val_accuracy: 0.9854 - val_dice_coef: 0.5294
# Epoch 15/50
# 61/61 [==============================] - 20s 329ms/step - loss: 0.0299 - accuracy: 0.9905 - dice_coef: 0.6488 - val_loss: 0.0491 - val_accuracy: 0.9859 - val_dice_coef: 0.5509
# Epoch 16/50
# 61/61 [==============================] - 21s 344ms/step - loss: 0.0272 - accuracy: 0.9911 - dice_coef: 0.6743 - val_loss: 0.0424 - val_accuracy: 0.9863 - val_dice_coef: 0.6087
# Epoch 17/50
# 61/61 [==============================] - 21s 337ms/step - loss: 0.0256 - accuracy: 0.9916 - dice_coef: 0.6932 - val_loss: 0.0420 - val_accuracy: 0.9872 - val_dice_coef: 0.5849
# Epoch 18/50
# 61/61 [==============================] - 21s 341ms/step - loss: 0.0232 - accuracy: 0.9923 - dice_coef: 0.7201 - val_loss: 0.0401 - val_accuracy: 0.9873 - val_dice_coef: 0.6145
# Epoch 19/50
# 61/61 [==============================] - 21s 348ms/step - loss: 0.0217 - accuracy: 0.9926 - dice_coef: 0.7348 - val_loss: 0.0417 - val_accuracy: 0.9872 - val_dice_coef: 0.6115
# Epoch 20/50
# 61/61 [==============================] - 21s 347ms/step - loss: 0.0210 - accuracy: 0.9927 - dice_coef: 0.7422 - val_loss: 0.0404 - val_accuracy: 0.9877 - val_dice_coef: 0.6234
# Epoch 21/50
# 61/61 [==============================] - 20s 334ms/step - loss: 0.0194 - accuracy: 0.9933 - dice_coef: 0.7612 - val_loss: 0.0401 - val_accuracy: 0.9879 - val_dice_coef: 0.6399
# Epoch 22/50
# 61/61 [==============================] - 20s 334ms/step - loss: 0.0176 - accuracy: 0.9938 - dice_coef: 0.7814 - val_loss: 0.0361 - val_accuracy: 0.9880 - val_dice_coef: 0.6419
# Epoch 23/50
# 61/61 [==============================] - 21s 351ms/step - loss: 0.0170 - accuracy: 0.9940 - dice_coef: 0.7877 - val_loss: 0.0347 - val_accuracy: 0.9889 - val_dice_coef: 0.6790
# Epoch 24/50
# 61/61 [==============================] - 21s 339ms/step - loss: 0.0156 - accuracy: 0.9944 - dice_coef: 0.8048 - val_loss: 0.0365 - val_accuracy: 0.9884 - val_dice_coef: 0.6937
# Epoch 25/50
# 61/61 [==============================] - 21s 339ms/step - loss: 0.0157 - accuracy: 0.9943 - dice_coef: 0.8055 - val_loss: 0.0353 - val_accuracy: 0.9893 - val_dice_coef: 0.6994
# Epoch 26/50
# 61/61 [==============================] - 20s 333ms/step - loss: 0.0143 - accuracy: 0.9948 - dice_coef: 0.8202 - val_loss: 0.0350 - val_accuracy: 0.9892 - val_dice_coef: 0.7102
# Epoch 27/50
# 61/61 [==============================] - 20s 331ms/step - loss: 0.0132 - accuracy: 0.9952 - dice_coef: 0.8335 - val_loss: 0.0382 - val_accuracy: 0.9888 - val_dice_coef: 0.7005
# Epoch 28/50
# 61/61 [==============================] - 20s 330ms/step - loss: 0.0128 - accuracy: 0.9953 - dice_coef: 0.8389 - val_loss: 0.0396 - val_accuracy: 0.9870 - val_dice_coef: 0.6955
# Attention UNet execution time is:  0:09:36.410525
# Save Model Path :  Brain_Tumor_UNet_50epochs.h5

# %% [markdown]
# ## Performance Accuracy, Loss , Dice ##

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4))
t = f.suptitle('Unet Performance in Segmentation', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = history.epoch

#for Accuracy
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, epoch_list[-1], 5))
ax1.set_ylabel('Accuracy Value');ax1.set_xlabel('Epoch');ax1.set_title('Accuracy')
ax1.legend(loc="best");ax1.grid(color='gray', linestyle='-', linewidth=0.5)

#for Loss
ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('Loss Value');ax2.set_xlabel('Epoch');ax2.set_title('Loss')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)


#for Dice Loss
ax3.plot(epoch_list, history.history['dice_coef'], label='Dice Loss')
ax3.plot(epoch_list, history.history['val_dice_coef'], label='Validation Dice Loss')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('Dice Loss Value');ax2.set_xlabel('Epoch');ax2.set_title('Loss')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
import pandas as pd
df = pd.read_csv("./saved/brain_tumor_unet_history.csv" , sep = ",")
plt.figure(figsize=(15, 5))
plt.plot(df.loss , 'b', label='Training loss')
plt.plot(df.val_loss, 'y', label='Validation loss')
plt.plot(df.dice_coef, 'r', label='Training Dice Coeff')
plt.plot(df.val_dice_coef , 'g', label='Validation Dice Coeff')
plt.title('LOSS / DICE COEFFICIENT', size=20)
plt.xlabel('Epochs', size=15)
plt.ylabel('Dice coefficient/ Loss', size=15)
plt.legend(loc="best");plt.grid(color='gray', linestyle='-', linewidth=0.5)
plt.show()

# %% [markdown]
# ## Load Model ##

# %%
unet_model = load_model('./Saved/Brain_Tumor_UNet_50epochs.h5', compile=False) #or compile = False
unet_model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', losses.dice_coef])

# %% [markdown]
# ## Predict Model ##

# %%
import random


idx = random.randint(0, len(X))
preds_train = unet_model.predict(X[:int(X.shape[0]*0.9)], verbose=1)
preds_val = unet_model.predict(X[int(X.shape[0]*0.9):], verbose=1)
preds_test = unet_model.predict(X_v, verbose=1)
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_test_t = (preds_test > 0.5).astype(np.uint8)
# Out:
# 61/61 [==============================] - 4s 72ms/step
# 7/7 [==============================] - 1s 82ms/step
# 29/29 [==============================] - 2s 72ms/step

# %%
ids = [752, 454, 887,100]
temp = np.ones_like( Y_v[0] )
THRESHOLD = 0.5
predicted_mask = (unet_model.predict(X_v)>THRESHOLD)*1
# Out:
# 2022-09-17 21:26:31.165954: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
plt.figure(figsize=(14, 14))
j=1
total=4
for i in range(0,len(ids)):
    plt.subplot(total,4,j);j+=1
    plt.imshow( np.squeeze(X_v[i],axis=-1), cmap='gray' )
    plt.title("MRI Image");plt.axis('off')

    plt.subplot(total,4,j);j+=1
    plt.imshow( np.squeeze(X_v[i],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - Y_v[i],axis=-1), alpha=0.2, cmap='Set1' )
    plt.title("Original Mask");plt.axis('off')

    plt.subplot(total,4,j);j+=1
    plt.imshow( np.squeeze(predicted_mask[i],axis=-1), cmap='gray' )
    plt.title("Predicted Mask");plt.axis('off')
    
    plt.subplot(total,4,j);j+=1
    plt.imshow( np.squeeze(X_v[i],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - predicted_mask[i],axis=-1),  alpha=0.2 ,  cmap='Set1')
    plt.title("Predicted Mask - "+processingObject.integer_to_class[str(processingObject.labels[i])]);plt.axis('off')
